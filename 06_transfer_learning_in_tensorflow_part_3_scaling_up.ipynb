# %% [markdown]
# # Transfer Learning with TensorFlow Part 3: Sclaing up (Food Vision mini)
#
# We've seen the power of transfer learning feature extraction and fine-tuning, now it's time to scale up to all of the classes in Food101 (101 total classes).
#
# Goal is to beat the Food101 paper with 10% of the data.

# %%
# Check GPU
# !nvidia-smi
# Out:
# Mon Jan 16 14:08:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 527.92.01    Driver Version: 528.02       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:04:00.0  On |                  N/A |
# | 53%   40C    P8    51W / 390W |    841MiB / 24576MiB |     11%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A        36      G   /Xwayland                       N/A      |
# +-----------------------------------------------------------------------------+

# %%
# Helper functions @ ./helper_functions.py

# %%
# Import series of helper functions from helper_functions.py
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir
# Out:
# 2023-01-16 14:08:53.872919: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-16 14:08:55.806382: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdirectml.d6f03b303ac3c4f2eeb8ca631688c9757b361310.so
# 2023-01-16 14:08:55.806451: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdxcore.so
# 2023-01-16 14:08:55.808410: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libd3d12.so
# 2023-01-16 14:08:56.095591: I tensorflow/c/logging.cc:34] DirectML device enumeration: found 1 compatible adapters.

# %% [markdown]
# ## 101 Food Classes : Working with less data

# %%
# Download, data has been modified using image_data_modification notebook on course github - https://github.com/mrdbourke/tensorflow-deep-learning/blob/main/06_transfer_learning_in_tensorflow_part_3_scaling_up.ipynb
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/101_food_classes_10_percent.zip
unzip_data("101_food_classes_10_percent.zip")
# Out:
# --2023-01-16 14:08:57--  https://storage.googleapis.com/ztm_tf_course/food_vision/101_food_classes_10_percent.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.138.128, 142.251.32.144, 142.251.33.16, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.138.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1625420029 (1.5G) [application/zip]
# Saving to: ‘101_food_classes_10_percent.zip.1’
#
# 101_food_classes_10 100%[===================>]   1.51G  85.0MB/s    in 17s
#
# 2023-01-16 14:09:14 (93.1 MB/s) - ‘101_food_classes_10_percent.zip.1’ saved [1625420029/1625420029]

# %%
unzip_data("101_food_classes_10_percent.zip")

# %%
# manually moving 101_food_classes_10_percent unzipped folder to the data folder

# %%
train_dir = "../data/101_food_classes_10_percent/train"
test_dir = "../data/101_food_classes_10_percent/test"

# %%
# how many images/classes are there
walk_through_dir("../data/101_food_classes_10_percent")
# Out:
# There are 2 directories and 0 images in '../data/101_food_classes_10_percent'.
# There are 101 directories and 0 images in '../data/101_food_classes_10_percent/test'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/macaroni_and_cheese'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/cannoli'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/fried_rice'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/grilled_cheese_sandwich'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/spring_rolls'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/apple_pie'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/chicken_curry'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/ceviche'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/red_velvet_cake'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/tiramisu'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/paella'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/creme_brulee'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/clam_chowder'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/baby_back_ribs'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/grilled_salmon'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/beignets'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/beef_carpaccio'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/lasagna'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/hummus'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/bread_pudding'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/chocolate_mousse'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/french_onion_soup'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/tacos'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/baklava'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/tuna_tartare'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/peking_duck'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/donuts'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/chicken_wings'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/sashimi'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/takoyaki'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/lobster_roll_sandwich'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/fried_calamari'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/bruschetta'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/falafel'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/nachos'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/huevos_rancheros'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/caesar_salad'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/hamburger'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/spaghetti_carbonara'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/ramen'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/seaweed_salad'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/sushi'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/waffles'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/escargots'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/hot_dog'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/greek_salad'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/lobster_bisque'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/churros'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/chocolate_cake'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/spaghetti_bolognese'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/caprese_salad'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/miso_soup'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/cup_cakes'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/pho'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/gyoza'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/french_toast'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/onion_rings'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/omelette'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/pad_thai'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/strawberry_shortcake'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/bibimbap'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/garlic_bread'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/mussels'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/beet_salad'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/fish_and_chips'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/ravioli'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/french_fries'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/scallops'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/ice_cream'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/croque_madame'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/frozen_yogurt'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/deviled_eggs'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/crab_cakes'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/pork_chop'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/carrot_cake'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/hot_and_sour_soup'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/samosa'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/poutine'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/club_sandwich'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/eggs_benedict'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/oysters'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/cheese_plate'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/prime_rib'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/pulled_pork_sandwich'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/breakfast_burrito'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/shrimp_and_grits'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/guacamole'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/risotto'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/beef_tartare'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/panna_cotta'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/gnocchi'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/steak'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/cheesecake'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/edamame'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/chicken_quesadilla'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/pancakes'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/filet_mignon'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/dumplings'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/pizza'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/macarons'.
# There are 0 directories and 250 images in '../data/101_food_classes_10_percent/test/foie_gras'.
# There are 101 directories and 0 images in '../data/101_food_classes_10_percent/train'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/macaroni_and_cheese'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/cannoli'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/fried_rice'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/grilled_cheese_sandwich'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/spring_rolls'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/apple_pie'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/chicken_curry'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/ceviche'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/red_velvet_cake'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/tiramisu'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/paella'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/creme_brulee'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/clam_chowder'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/baby_back_ribs'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/grilled_salmon'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/beignets'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/beef_carpaccio'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/lasagna'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/hummus'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/bread_pudding'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/chocolate_mousse'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/french_onion_soup'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/tacos'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/baklava'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/tuna_tartare'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/peking_duck'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/donuts'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/chicken_wings'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/sashimi'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/takoyaki'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/lobster_roll_sandwich'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/fried_calamari'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/bruschetta'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/falafel'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/nachos'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/huevos_rancheros'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/caesar_salad'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/hamburger'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/spaghetti_carbonara'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/ramen'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/seaweed_salad'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/sushi'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/waffles'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/escargots'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/hot_dog'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/greek_salad'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/lobster_bisque'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/churros'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/chocolate_cake'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/spaghetti_bolognese'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/caprese_salad'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/miso_soup'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/cup_cakes'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/pho'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/gyoza'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/french_toast'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/onion_rings'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/omelette'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/pad_thai'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/strawberry_shortcake'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/bibimbap'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/garlic_bread'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/mussels'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/beet_salad'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/fish_and_chips'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/ravioli'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/french_fries'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/scallops'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/ice_cream'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/croque_madame'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/frozen_yogurt'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/deviled_eggs'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/crab_cakes'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/pork_chop'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/carrot_cake'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/hot_and_sour_soup'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/samosa'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/poutine'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/club_sandwich'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/eggs_benedict'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/oysters'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/cheese_plate'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/prime_rib'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/pulled_pork_sandwich'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/breakfast_burrito'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/shrimp_and_grits'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/guacamole'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/risotto'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/beef_tartare'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/panna_cotta'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/gnocchi'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/steak'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/cheesecake'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/edamame'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/chicken_quesadilla'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/pancakes'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/filet_mignon'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/dumplings'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/pizza'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/macarons'.
# There are 0 directories and 75 images in '../data/101_food_classes_10_percent/train/foie_gras'.

# %%
# Set up data inputs
import tensorflow as tf
IMG_SIZE = (224, 224)
train_data_all_10_percent= tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                               label_mode="categorical",
                                                                               image_size=IMG_SIZE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                                label_mode="categorical",
                                                                image_size=IMG_SIZE,
                                                               shuffle=False) # don't shuffle test data for prediction analysis
# Out:
# Found 7575 files belonging to 101 classes.
# 2023-01-16 14:09:29.962462: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-16 14:09:29.965153: I tensorflow/c/logging.cc:34] DirectML: creating device on adapter 0 (NVIDIA GeForce RTX 3090)
# 2023-01-16 14:09:30.112591: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:09:30.112620: W tensorflow/core/common_runtime/pluggable_device/pluggable_device_bfc_allocator.cc:28] Overriding allow_growth setting because force_memory_growth was requested by the device.
# 2023-01-16 14:09:30.112636: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:09:30.113630: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Found 25250 files belonging to 101 classes.

# %% [markdown]
# ## Train a big dog model with transfer learning on 10% of the 101 food classes
#
# Steps:
# * Create a `ModelCheckpoint` callback
# * Create a data augmentation layer to build data augmentation right into the model
# * Build a headless (no top layers) Functional EfficientNetB0 backboned-model (we'll create our own output layer)
# * Compile our model
# * Feature extract for 5 epochs, and 15% of teh test data to save time

# %%
# Create a ModelCheckpoint
checkpoint_path = "101_classes_10_percent_data_model_checkpoint"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                        save_weights_only=True,
                                                        monitor="val_accuracy",
                                                        save_best_only=True)

# %%
# Create data augmentation layer to incorporate it right into the model
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential

# Setup data augmentation
data_augmentation = Sequential([
    preprocessing.RandomFlip("horizontal"),
    preprocessing.RandomRotation(0.2),
    preprocessing.RandomHeight(0.2),
    preprocessing.RandomHeight(0.2),
    preprocessing.RandomWidth(0.2),
    preprocessing.RandomZoom(0.2)
    # preprocessing.Rescaling(1/255.) # rescale inputs between 0 and 1, required for models like resnet 50
], name="data_augmentation")

# %%
# Setup the base model and freeze its layers (this will extract features)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)
base_model.trainable = False

# Setup model architecture with trainable top layers
inputs = layers.Input(shape=(224, 224, 3), name="input_layer")
x = data_augmentation(inputs) # augment images (only happens during the training phase)
x = base_model(x, training=False) # put the model in inference mode so weights stay frozen
x = layers.GlobalAveragePooling2D(name="global_avg_pool_layer")(x)
outputs = layers.Dense(len(train_data_all_10_percent.class_names), activation = "softmax", name="output_layer")(x)
model = tf.keras.Model(inputs, outputs)

# %%
# get a summary of model we created
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, 224, 224, 3)      0
#  al)
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_avg_pool_layer (Glob  (None, 1280)             0
#  alAveragePooling2D)
#
#  output_layer (Dense)        (None, 101)               129381
#
# =================================================================
# Total params: 4,178,952
# Trainable params: 129,381
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
with tf.device("/GPU:0"):
    # Compile
    model.compile(loss="categorical_crossentropy",
                  optimizer= tf.keras.optimizers.Adam(),
                  metrics=["accuracy"])

    # fit
    history_all_classes_10_percent = model.fit(train_data_all_10_percent,
                                               epochs=5,
                                               validation_data=test_data,
                                               validation_steps=int(0.15 * len(test_data)),
                                               callbacks=[checkpoint_callback])
# Out:
# Epoch 1/5
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 2023-01-16 14:23:49.796226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-01-16 14:23:50.478406: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.478493: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.478537: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.479081: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.479102: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.479130: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.481189: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.481270: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.481344: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.481893: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.483894: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.483999: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.485477: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.485512: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.485536: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.485898: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.485931: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.485954: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.486259: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.486328: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.486386: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.486873: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.486903: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.486928: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.487261: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.487346: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.487411: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.487895: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.488016: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.488133: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.488499: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.488539: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.488580: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.488972: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.489036: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.489087: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.489519: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.489560: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.489591: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.489938: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.489981: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.490012: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.492649: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.492694: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.492727: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.493155: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.493227: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.493307: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.493776: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.493889: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.493998: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.494702: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.494732: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.494877: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.495251: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.495293: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.495333: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.495752: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.495793: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.495819: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.496180: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.496213: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.496237: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.496567: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.496600: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.496624: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.496999: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.497051: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.497074: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.497602: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.497645: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.497669: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.498084: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.498124: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.498153: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.498383: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.498401: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.498422: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.498650: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.498668: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.498688: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.499542: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.499693: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.499726: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.500077: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.500097: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.500128: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.500444: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.500500: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.500536: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.500899: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.500935: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.500959: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.501430: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.501456: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.501482: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.501768: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.501787: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.501808: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.502062: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.502082: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.502116: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.502677: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.502705: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.502745: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.503833: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.503906: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.503951: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.504289: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.504346: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.504408: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.504960: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.505026: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.505075: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.505518: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.505592: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.505689: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.506411: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.506481: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.506700: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.507048: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.507154: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.507211: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.507770: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.507807: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.507831: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.508097: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.508131: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.508153: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.508580: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.508612: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.508673: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.509867: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.509911: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.510002: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.511974: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.512023: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.512044: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.515084: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.515190: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.515238: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.515962: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.515998: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.516022: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.516370: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.516471: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.516535: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.517218: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.517293: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.517375: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.517692: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.517787: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.517872: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.518494: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.518545: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.518593: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.518912: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.519003: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.519069: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.519695: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.519754: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.519802: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.520106: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.520168: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.520219: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.520747: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.520826: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.520902: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.521203: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.521243: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.521279: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.521665: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.521705: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.521740: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.521941: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.521978: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.522013: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.522415: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.522453: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.522486: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.522720: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.522758: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.522791: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.523325: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.523363: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.523396: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:23:50.523611: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:23:50.523665: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:23:50.523702: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ...
# 2023-01-16 14:30:56.479751: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.480044: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.480080: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.480103: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.480699: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.480766: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.480819: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.481240: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.481274: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.481298: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.481825: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.481865: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.481890: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.482206: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.482274: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.482307: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.482831: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.482870: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.482900: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.483200: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.483279: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.483325: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.484018: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.484061: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.484089: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.484419: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.484461: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.484490: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.485196: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.485275: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.485319: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.485870: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.485906: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.485933: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.486526: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.486566: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.486597: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.487485: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.487524: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.487550: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.488142: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.488211: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.488279: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.488673: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.488711: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.488734: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.489272: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.489330: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.489375: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.489826: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.489876: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.489907: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.490676: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.490719: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.490750: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.491088: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.491123: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.491147: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.491793: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.491871: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.491917: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-16 14:30:56.492512: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-16 14:30:56.492556: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 83006 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2023-01-16 14:30:56.492585: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 237/237 [==============================] - 438s 2s/step - loss: 1.8239 - accuracy: 0.5624 - val_loss: 1.9252 - val_accuracy: 0.5061
# Epoch 2/5
# 237/237 [==============================] - 666s 3s/step - loss: 1.5911 - accuracy: 0.6065 - val_loss: 1.8296 - val_accuracy: 0.5267
# Epoch 3/5
# 237/237 [==============================] - 642s 3s/step - loss: 1.4361 - accuracy: 0.6455 - val_loss: 1.7445 - val_accuracy: 0.5434
# Epoch 4/5
# 237/237 [==============================] - 431s 2s/step - loss: 1.3128 - accuracy: 0.6754 - val_loss: 1.7717 - val_accuracy: 0.5392
# Epoch 5/5
# 189/237 [======================>.......] - ETA: 41s - loss: 1.2249 - accuracy: 0.6959

# %%
fine_tuning_results = model.evaluate(test_data)

# %%
plot_loss_curves(history_all_classes_10_percent)

# %% [markdown]
# ## Fine-tuning

# %%
# Unfreeze all of the layers in the base model
base_model.trainable = True

# Refreeze every layer except last 5
for layer in base_model.layers[:-5]:
    layer.trainable = False

# %%
# recompile model with lower learning rate (lower by 10x)
model.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(learning_rate=.0001),
              metrics=["accuracy"])

# %%
# what layers in the model are trainable
for layer in model.layers:
    print(layer.name, layer.trainable)

# %%
# check which layers are trainable in base_model
for layer_number, layer in enumerate(model.layers[2].layers):
    print(layer_number, layer.name, layer.trainable)

# %%
tf.debugging.set_log_device_placement(True)


# with tf.device('/GPU:0'): 
# Fine-tune for 5 more people
fine_tune_epochs = 10 # model has done 5 already, this is the total desired.

# fine-tune our model
history_all_classes_10_percent = model.fit(train_data_all_10_percent,
                                           epochs=fine_tune_epochs,
                                           validation_data = test_data,
                                           validation_steps = int(0.15 * len(test_data)),
                                           initial_epoch=history_all_classes_10_percent.epoch[-1])
